# %% [markdown]
# # Capturing webcam video

# %%
import cv2 
from PIL import Image

# %%
# define a video capture object 
vid = cv2.VideoCapture(0)
# Out:
# [ WARN:0@3.617] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 2023-10-28 14:22:19.617 python[19862:995844] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.

# %%
ret, frame = vid.read()

# %%
# Convert the BGR frame to RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# Create a PIL image from the NumPy array
pil_image = Image.fromarray(frame_rgb)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
vid.release()
